# %%
from StyleTransferDataset import StyleTransferDataset
import StyleTransferTrain
from matplotlib import pyplot as plt

# %%
num_epochs = 500

# %%
# configure layers & weights
style_layers = ['r11','r21','r31','r41', 'r51'] 
content_layers = ['r42']

## Configure Weights
style_weights = [1e3/n**2 for n in [64,128,256,512,512]]
content_weights = [1e1]

# %%
dataset = StyleTransferDataset(800)

# %%
plt.imshow(dataset[0][1])
# Out:
# /Users/savyasachi/let-it-gogh/neural-style-transfer/Images/Style/
# /Users/savyasachi/let-it-gogh/neural-style-transfer/Images/Content/

# %%
for d in dataset:
    output = StyleTransferTrain.train(d, style_layers, content_layers, style_weights, content_weights, num_epochs)
# Out:
# /Users/savyasachi/let-it-gogh/neural-style-transfer/Images/Style/
# /Users/savyasachi/let-it-gogh/neural-style-transfer/Images/Content/
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-3278e928353e> in <module>
#       1 for d in dataset:
# ----> 2     output = StyleTransferTrain.train(d, style_layers, content_layers, style_weights, content_weights, num_epochs)
#
# ~/let-it-gogh/neural-style-transfer/StyleTransferTrain.py in train(T, style_layers, content_layers, style_weights, content_weights, num_epochs)
#      30     optimizer = optim.LBFGS([opt_img]);
#      31     net, loss_layers, loss_fns, targets = StyleTransferNet.init(
# ---> 32         style_image, content_image, style_layers, content_layers)
#      33
#      34     n_iter = 0
#
# ~/let-it-gogh/neural-style-transfer/StyleTransferNet.py in init(style_image, content_image, style_layers, content_layers)
#      55
#      56     loss_layers = style_layers + content_layers
# ---> 57     loss_fns = [GramMSELoss()] * len(style_layers) + [nn.MSELoss()] * len(content_layers)
#      58     loss_fns = [loss_fn.to(device) for loss_fn in loss_fns]
#      59
#
# TypeError: GramMSELoss() missing 2 required positional arguments: 'input' and 'target'
