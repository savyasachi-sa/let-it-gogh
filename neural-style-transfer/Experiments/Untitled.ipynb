# %%
import sys
sys.path.insert(1, '../')

from StyleTransferDataset import StyleTransferDataset
import StyleTransferTrain
from matplotlib import pyplot as plt

image_dir = '../Images/'

num_epochs = 500

# %%
dataset = StyleTransferDataset(img_dir=image_dir)

# %%
d = dataset[5]

# %%
plt.imshow(d[0])

# %%
style_layers = ['r11','r21','r31','r41'] 
content_layers = ['r42']

## Configure Weights
style_weights = [1e3/n**2 for n in [64,128,256,64,64]]
content_weights = [1e1]

output = StyleTransferTrain.train(d, style_layers, content_layers, style_weights, content_weights, num_epochs)

fig = plt.figure(figsize=(10, 10))
plt.imshow(output)
# Out:
# 49 Completed
# 99 Completed
# 149 Completed
# 199 Completed
# 249 Completed
# 299 Completed
# 349 Completed
# 399 Completed
# 449 Completed
# 499 Completed

# %%
dataset = StyleTransferDataset(img_dir=image_dir)
d = dataset[6]

# %%
style_layers = ['r11','r21','r31','r41'] 
content_layers = ['r42']

## Configure Weights
style_weights = [1e3/n**2 for n in [64,128,256,64]]
content_weights = [1e1]

output = StyleTransferTrain.train(d, style_layers, content_layers, style_weights, content_weights, num_epochs)

fig = plt.figure(figsize=(10, 10))
plt.imshow(output)
# Out:
# 49 Completed
# 99 Completed
# 149 Completed
# 199 Completed
# 249 Completed
# 299 Completed
# 349 Completed
# 399 Completed
# 449 Completed
# 499 Completed
